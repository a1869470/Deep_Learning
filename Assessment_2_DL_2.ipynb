# %% [markdown]
# <a href="https://colab.research.google.com/github/a1869470/Deep_Learning/blob/main/Assessment_2_DL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet, Xception, DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Load CIFAR-10 dataset
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
num_classes = 10

# Split the full training dataset into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# Define function to create a CNN model with fine-tuning
def create_fine_tuned_model(base_model, num_classes, num_frozen_layers=100, learning_rate=0.0001):
    for layer in base_model.layers[:num_frozen_layers]:
        layer.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and compile fine-tuned models
resnet_model = create_fine_tuned_model(ResNet50(weights='imagenet', include_top=False), num_classes)
vgg_model = create_fine_tuned_model(VGG16(weights='imagenet', include_top=False), num_classes)
mobilenet_model = create_fine_tuned_model(MobileNet(weights='imagenet', include_top=False), num_classes)
xception_model = create_fine_tuned_model(Xception(weights='imagenet', include_top=False), num_classes)
densenet_model = create_fine_tuned_model(DenseNet121(weights='imagenet', include_top=False), num_classes)

# Train and evaluate fine-tuned models
models = [resnet_model, vgg_model, mobilenet_model, xception_model, densenet_model]
model_names = ['ResNet', 'VGG', 'MobileNet', 'Xception', 'DenseNet121']
histories = []

for model, model_name in zip(models, model_names):
    print(f"Fine-tuning and training {model_name}...")
    history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_val, y_val))
    histories.append(history)
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"{model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Find the two models with the highest test accuracy
top_models = sorted(zip(models, model_names), key=lambda x: x[0].evaluate(x_test, y_test)[1], reverse=True)[:2]

# Evaluate the two best models on the test data
for model, model_name in top_models:
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Best Model: {model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Plot the line graph for validation accuracy
for i, history in enumerate(histories):
    plt.plot(history.history['val_accuracy'], label=f'{model_names[i]}')

plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Fine-tuning and training ResNet...
# Epoch 1/10
# 625/625 [==============================] - 39s 38ms/step - loss: 1.9021 - accuracy: 0.3359 - val_loss: 2.1996 - val_accuracy: 0.2650
# Epoch 2/10
# 625/625 [==============================] - 22s 35ms/step - loss: 1.5738 - accuracy: 0.4464 - val_loss: 2.0123 - val_accuracy: 0.2990
# Epoch 3/10
# 625/625 [==============================] - 22s 35ms/step - loss: 1.4659 - accuracy: 0.4837 - val_loss: 1.9942 - val_accuracy: 0.3700
# Epoch 4/10
# 625/625 [==============================] - 22s 35ms/step - loss: 1.3786 - accuracy: 0.5145 - val_loss: 1.9371 - val_accuracy: 0.3354
# Epoch 5/10
# 625/625 [==============================] - 22s 35ms/step - loss: 1.3186 - accuracy: 0.5340 - val_loss: 1.9593 - val_accuracy: 0.3066
# Epoch 6/10
# 625/625 [==============================] - 25s 40ms/step - loss: 1.2794 - accuracy: 0.5497 - val_loss: 1.9163 - val_accuracy: 0.3580
# Epoch 7/10
# 625/625 [==============================] - 23s 36ms/step - loss: 1.2282 - accuracy: 0.5685 - val_loss: 1.7897 - val_accuracy: 0.3800
# Epoch 8/10
# 625/625 [==============================] - 22s 36ms/step - loss: 1.1663 - accuracy: 0.5893 - val_loss: 1.9623 - val_accuracy: 0.3428
# Epoch 9/10
# 625/625 [==============================] - 22s 36ms/step - loss: 1.0867 - accuracy: 0.6155 - val_loss: 2.0505 - val_accuracy: 0.3796
# Epoch 10/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.9973 - accuracy: 0.6467 - val_loss: 2.1623 - val_accuracy: 0.3198
# ResNet - Test loss: 2.2007434368133545; Test accuracy: 0.3172000050544739
# Fine-tuning and training VGG...
# Epoch 1/10
# 625/625 [==============================] - 10s 13ms/step - loss: 1.6196 - accuracy: 0.4590 - val_loss: 1.4050 - val_accuracy: 0.5166
# Epoch 2/10
# 625/625 [==============================] - 8s 13ms/step - loss: 1.3310 - accuracy: 0.5446 - val_loss: 1.3066 - val_accuracy: 0.5444
# Epoch 3/10
# 625/625 [==============================] - 8s 12ms/step - loss: 1.2540 - accuracy: 0.5698 - val_loss: 1.2545 - val_accuracy: 0.5670
# Epoch 4/10
# 625/625 [==============================] - 8s 12ms/step - loss: 1.2089 - accuracy: 0.5856 - val_loss: 1.2198 - val_accuracy: 0.5796
# Epoch 5/10
# 625/625 [==============================] - 7s 12ms/step - loss: 1.1778 - accuracy: 0.5946 - val_loss: 1.2111 - val_accuracy: 0.5762
# Epoch 6/10
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1524 - accuracy: 0.6021 - val_loss: 1.1869 - val_accuracy: 0.5848
# Epoch 7/10
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1315 - accuracy: 0.6102 - val_loss: 1.1849 - val_accuracy: 0.5844
# Epoch 8/10
# 625/625 [==============================] - 7s 12ms/step - loss: 1.1128 - accuracy: 0.6192 - val_loss: 1.1589 - val_accuracy: 0.5956
# Epoch 9/10
# 625/625 [==============================] - 7s 12ms/step - loss: 1.0973 - accuracy: 0.6234 - val_loss: 1.1607 - val_accuracy: 0.5892
# Epoch 10/10
# 625/625 [==============================] - 8s 12ms/step - loss: 1.0827 - accuracy: 0.6270 - val_loss: 1.1567 - val_accuracy: 0.5938
# VGG - Test loss: 1.1486666202545166; Test accuracy: 0.5952000021934509
# Fine-tuning and training MobileNet...
# Epoch 1/10
# 625/625 [==============================] - 8s 9ms/step - loss: 2.2295 - accuracy: 0.1798 - val_loss: 2.1949 - val_accuracy: 0.2046
# Epoch 2/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1768 - accuracy: 0.2094 - val_loss: 2.1726 - val_accuracy: 0.2192
# Epoch 3/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1581 - accuracy: 0.2187 - val_loss: 2.1603 - val_accuracy: 0.2250
# Epoch 4/10
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1473 - accuracy: 0.2227 - val_loss: 2.1539 - val_accuracy: 0.2304
# Epoch 5/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1413 - accuracy: 0.2237 - val_loss: 2.1497 - val_accuracy: 0.2328
# Epoch 6/10
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1367 - accuracy: 0.2255 - val_loss: 2.1462 - val_accuracy: 0.2302
# Epoch 7/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1332 - accuracy: 0.2279 - val_loss: 2.1438 - val_accuracy: 0.2312
# Epoch 8/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1303 - accuracy: 0.2269 - val_loss: 2.1425 - val_accuracy: 0.2346
# Epoch 9/10
# 625/625 [==============================] - 5s 8ms/step - loss: 2.1277 - accuracy: 0.2292 - val_loss: 2.1395 - val_accuracy: 0.2362
# Epoch 10/10
# 625/625 [==============================] - 4s 7ms/step - loss: 2.1254 - accuracy: 0.2304 - val_loss: 2.1388 - val_accuracy: 0.2338
# MobileNet - Test loss: 2.140302896499634; Test accuracy: 0.22619999945163727
# Fine-tuning and training Xception...
# Epoch 1/10
# 625/625 [==============================] - 32s 38ms/step - loss: 1.4963 - accuracy: 0.4836 - val_loss: 1.0088 - val_accuracy: 0.6540
# Epoch 2/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.8684 - accuracy: 0.6986 - val_loss: 0.9048 - val_accuracy: 0.6908
# Epoch 3/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.6030 - accuracy: 0.7893 - val_loss: 0.9318 - val_accuracy: 0.6954
# Epoch 4/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.3873 - accuracy: 0.8662 - val_loss: 1.0287 - val_accuracy: 0.6946
# Epoch 5/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.2326 - accuracy: 0.9200 - val_loss: 1.2122 - val_accuracy: 0.6878
# Epoch 6/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.1589 - accuracy: 0.9455 - val_loss: 1.2721 - val_accuracy: 0.6892
# Epoch 7/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.1182 - accuracy: 0.9603 - val_loss: 1.4591 - val_accuracy: 0.6736
# Epoch 8/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0987 - accuracy: 0.9653 - val_loss: 1.4974 - val_accuracy: 0.6896
# Epoch 9/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0916 - accuracy: 0.9693 - val_loss: 1.5763 - val_accuracy: 0.6718
# Epoch 10/10
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0713 - accuracy: 0.9761 - val_loss: 1.6490 - val_accuracy: 0.6928
# Xception - Test loss: 1.8109203577041626; Test accuracy: 0.6740000247955322
# Fine-tuning and training DenseNet121...
# Epoch 1/10
# 625/625 [==============================] - 86s 68ms/step - loss: 1.1932 - accuracy: 0.5847 - val_loss: 0.8626 - val_accuracy: 0.7036
# Epoch 2/10
# 625/625 [==============================] - 40s 64ms/step - loss: 0.6630 - accuracy: 0.7699 - val_loss: 0.6608 - val_accuracy: 0.7746
# Epoch 3/10
# 625/625 [==============================] - 42s 67ms/step - loss: 0.4545 - accuracy: 0.8416 - val_loss: 0.6704 - val_accuracy: 0.7768
# Epoch 4/10
# 625/625 [==============================] - 41s 65ms/step - loss: 0.3012 - accuracy: 0.8973 - val_loss: 0.7118 - val_accuracy: 0.7850
# Epoch 5/10
# 625/625 [==============================] - 41s 66ms/step - loss: 0.2125 - accuracy: 0.9270 - val_loss: 0.7478 - val_accuracy: 0.7838
# Epoch 6/10
# 625/625 [==============================] - 41s 65ms/step - loss: 0.1518 - accuracy: 0.9465 - val_loss: 0.7865 - val_accuracy: 0.7942
# Epoch 7/10
# 625/625 [==============================] - 40s 65ms/step - loss: 0.1211 - accuracy: 0.9582 - val_loss: 0.8432 - val_accuracy: 0.7936
# Epoch 8/10
# 625/625 [==============================] - 40s 64ms/step - loss: 0.1060 - accuracy: 0.9629 - val_loss: 0.8677 - val_accuracy: 0.7964
# Epoch 9/10
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0930 - accuracy: 0.9680 - val_loss: 0.9023 - val_accuracy: 0.7990
# Epoch 10/10
# 625/625 [==============================] - 40s 64ms/step - loss: 0.0833 - accuracy: 0.9725 - val_loss: 0.9159 - val_accuracy: 0.7972
# DenseNet121 - Test loss: 0.9611673951148987; Test accuracy: 0.7972000241279602
# 157/157 [==============================] - 2s 12ms/step - loss: 2.2007 - accuracy: 0.3172
# 157/157 [==============================] - 1s 9ms/step - loss: 1.1487 - accuracy: 0.5952
# 157/157 [==============================] - 1s 6ms/step - loss: 2.1403 - accuracy: 0.2262
# 157/157 [==============================] - 2s 10ms/step - loss: 1.8109 - accuracy: 0.6740
# 157/157 [==============================] - 2s 14ms/step - loss: 0.9612 - accuracy: 0.7972
# Best Model: DenseNet121 - Test loss: 0.9611673951148987; Test accuracy: 0.7972000241279602
# Best Model: Xception - Test loss: 1.8109203577041626; Test accuracy: 0.6740000247955322
