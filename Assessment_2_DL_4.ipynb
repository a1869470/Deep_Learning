# %% [markdown]
# <a href="https://colab.research.google.com/github/a1869470/Deep_Learning/blob/main/Assessment_2_DL_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet, Xception, DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Load CIFAR-10 dataset
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
num_classes = 10

# Split the full training dataset into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# Define function to create a CNN model with fine-tuning
def create_fine_tuned_model(base_model, num_classes, num_frozen_layers=100, learning_rate=0.001):
    for layer in base_model.layers[:num_frozen_layers]:
        layer.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and compile fine-tuned models
resnet_model = create_fine_tuned_model(ResNet50(weights='imagenet', include_top=False), num_classes)
vgg_model = create_fine_tuned_model(VGG16(weights='imagenet', include_top=False), num_classes)
mobilenet_model = create_fine_tuned_model(MobileNet(weights='imagenet', include_top=False), num_classes)
xception_model = create_fine_tuned_model(Xception(weights='imagenet', include_top=False), num_classes)
densenet_model = create_fine_tuned_model(DenseNet121(weights='imagenet', include_top=False), num_classes)

# Train and evaluate fine-tuned models
models = [resnet_model, vgg_model, mobilenet_model, xception_model, densenet_model]
model_names = ['ResNet', 'VGG', 'MobileNet', 'Xception', 'DenseNet121']
histories = []

for model, model_name in zip(models, model_names):
    print(f"Fine-tuning and training {model_name}...")
    history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val))
    histories.append(history)
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"{model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Find the two models with the highest test accuracy
top_models = sorted(zip(models, model_names), key=lambda x: x[0].evaluate(x_test, y_test)[1], reverse=True)[:2]

# Evaluate the two best models on the test data
for model, model_name in top_models:
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Best Model: {model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Plot the line graph for validation accuracy
for i, history in enumerate(histories):
    plt.plot(history.history['val_accuracy'], label=f'{model_names[i]}')

plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Fine-tuning and training ResNet...
# Epoch 1/10
# 1250/1250 [==============================] - 66s 33ms/step - loss: 1.7484 - accuracy: 0.3951 - val_loss: 3.5181 - val_accuracy: 0.1268
# Epoch 2/10
# 1250/1250 [==============================] - 41s 33ms/step - loss: 1.4789 - accuracy: 0.4800 - val_loss: 3.5741 - val_accuracy: 0.1004
# Epoch 3/10
# 1250/1250 [==============================] - 41s 33ms/step - loss: 1.4073 - accuracy: 0.5063 - val_loss: 2.3922 - val_accuracy: 0.0812
# Epoch 4/10
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.3526 - accuracy: 0.5268 - val_loss: 2.5395 - val_accuracy: 0.1458
# Epoch 5/10
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.2645 - accuracy: 0.5544 - val_loss: 4.2994 - val_accuracy: 0.1348
# Epoch 6/10
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.2447 - accuracy: 0.5612 - val_loss: 21.6884 - val_accuracy: 0.1132
# Epoch 7/10
# 1250/1250 [==============================] - 41s 33ms/step - loss: 1.2040 - accuracy: 0.5745 - val_loss: 3.0328 - val_accuracy: 0.1398
# Epoch 8/10
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.1571 - accuracy: 0.5910 - val_loss: 4.1114 - val_accuracy: 0.1320
# Epoch 9/10
# 1250/1250 [==============================] - 41s 33ms/step - loss: 1.0939 - accuracy: 0.6152 - val_loss: 6.9311 - val_accuracy: 0.1550
# Epoch 10/10
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.0263 - accuracy: 0.6377 - val_loss: 4.6272 - val_accuracy: 0.1596
# ResNet - Test loss: 4.767635345458984; Test accuracy: 0.1565999984741211
# Fine-tuning and training VGG...
# Epoch 1/10
# 1250/1250 [==============================] - 15s 11ms/step - loss: 1.3423 - accuracy: 0.5281 - val_loss: 1.2129 - val_accuracy: 0.5790
# Epoch 2/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.1603 - accuracy: 0.5919 - val_loss: 1.1801 - val_accuracy: 0.5796
# Epoch 3/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.0809 - accuracy: 0.6219 - val_loss: 1.1296 - val_accuracy: 0.6070
# Epoch 4/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.0165 - accuracy: 0.6413 - val_loss: 1.1182 - val_accuracy: 0.6054
# Epoch 5/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.9612 - accuracy: 0.6612 - val_loss: 1.1026 - val_accuracy: 0.6136
# Epoch 6/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.9079 - accuracy: 0.6789 - val_loss: 1.1206 - val_accuracy: 0.6174
# Epoch 7/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.8564 - accuracy: 0.6975 - val_loss: 1.1233 - val_accuracy: 0.6220
# Epoch 8/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.8036 - accuracy: 0.7168 - val_loss: 1.1453 - val_accuracy: 0.6116
# Epoch 9/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.7529 - accuracy: 0.7337 - val_loss: 1.1496 - val_accuracy: 0.6256
# Epoch 10/10
# 1250/1250 [==============================] - 12s 10ms/step - loss: 0.7022 - accuracy: 0.7530 - val_loss: 1.1533 - val_accuracy: 0.6262
# VGG - Test loss: 1.1400569677352905; Test accuracy: 0.626800000667572
# Fine-tuning and training MobileNet...
# Epoch 1/10
# 1250/1250 [==============================] - 11s 7ms/step - loss: 2.1625 - accuracy: 0.2104 - val_loss: 2.1427 - val_accuracy: 0.2316
# Epoch 2/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.1331 - accuracy: 0.2243 - val_loss: 2.1392 - val_accuracy: 0.2224
# Epoch 3/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 2.1242 - accuracy: 0.2279 - val_loss: 2.1294 - val_accuracy: 0.2278
# Epoch 4/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.1177 - accuracy: 0.2326 - val_loss: 2.1364 - val_accuracy: 0.2310
# Epoch 5/10
# 1250/1250 [==============================] - 7s 6ms/step - loss: 2.1132 - accuracy: 0.2335 - val_loss: 2.1291 - val_accuracy: 0.2372
# Epoch 6/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.1088 - accuracy: 0.2354 - val_loss: 2.1326 - val_accuracy: 0.2288
# Epoch 7/10
# 1250/1250 [==============================] - 9s 7ms/step - loss: 2.1043 - accuracy: 0.2374 - val_loss: 2.1330 - val_accuracy: 0.2294
# Epoch 8/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.1012 - accuracy: 0.2381 - val_loss: 2.1388 - val_accuracy: 0.2350
# Epoch 9/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.0993 - accuracy: 0.2401 - val_loss: 2.1341 - val_accuracy: 0.2314
# Epoch 10/10
# 1250/1250 [==============================] - 8s 6ms/step - loss: 2.0961 - accuracy: 0.2397 - val_loss: 2.1362 - val_accuracy: 0.2276
# MobileNet - Test loss: 2.132699966430664; Test accuracy: 0.2295999974012375
# Fine-tuning and training Xception...
# Epoch 1/10
# 1250/1250 [==============================] - 42s 26ms/step - loss: 1.3743 - accuracy: 0.5219 - val_loss: 0.9789 - val_accuracy: 0.6734
# Epoch 2/10
# 1250/1250 [==============================] - 32s 26ms/step - loss: 0.9671 - accuracy: 0.6733 - val_loss: 0.8885 - val_accuracy: 0.7006
# Epoch 3/10
# 1250/1250 [==============================] - 33s 26ms/step - loss: 0.8225 - accuracy: 0.7183 - val_loss: 0.8204 - val_accuracy: 0.7214
# Epoch 4/10
# 1250/1250 [==============================] - 33s 26ms/step - loss: 0.7038 - accuracy: 0.7575 - val_loss: 0.8211 - val_accuracy: 0.7266
# Epoch 5/10
# 1250/1250 [==============================] - 32s 26ms/step - loss: 0.5939 - accuracy: 0.7950 - val_loss: 0.8853 - val_accuracy: 0.7134
# Epoch 6/10
# 1250/1250 [==============================] - 33s 27ms/step - loss: 0.4830 - accuracy: 0.8336 - val_loss: 0.8847 - val_accuracy: 0.7246
# Epoch 7/10
# 1250/1250 [==============================] - 33s 27ms/step - loss: 0.3908 - accuracy: 0.8676 - val_loss: 0.9039 - val_accuracy: 0.7304
# Epoch 8/10
# 1250/1250 [==============================] - 32s 26ms/step - loss: 0.3114 - accuracy: 0.8942 - val_loss: 0.9502 - val_accuracy: 0.7248
# Epoch 9/10
# 1250/1250 [==============================] - 33s 27ms/step - loss: 0.2460 - accuracy: 0.9166 - val_loss: 1.0783 - val_accuracy: 0.7166
# Epoch 10/10
# 1250/1250 [==============================] - 32s 26ms/step - loss: 0.2064 - accuracy: 0.9273 - val_loss: 1.0984 - val_accuracy: 0.7218
# Xception - Test loss: 1.1195259094238281; Test accuracy: 0.718999981880188
# Fine-tuning and training DenseNet121...
# Epoch 1/10
# 1250/1250 [==============================] - 130s 66ms/step - loss: 0.9950 - accuracy: 0.6687 - val_loss: 2.5253 - val_accuracy: 0.6522
# Epoch 2/10
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.7254 - accuracy: 0.7537 - val_loss: 0.8549 - val_accuracy: 0.7500
# Epoch 3/10
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.5895 - accuracy: 0.7995 - val_loss: 0.5845 - val_accuracy: 0.7996
# Epoch 4/10
# 1250/1250 [==============================] - 82s 66ms/step - loss: 0.4826 - accuracy: 0.8370 - val_loss: 0.5709 - val_accuracy: 0.8112
# Epoch 5/10
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.4277 - accuracy: 0.8547 - val_loss: 0.5874 - val_accuracy: 0.8080
# Epoch 6/10
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.3496 - accuracy: 0.8794 - val_loss: 0.6521 - val_accuracy: 0.7942
# Epoch 7/10
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.3026 - accuracy: 0.8966 - val_loss: 0.7044 - val_accuracy: 0.7886
# Epoch 8/10
# 1250/1250 [==============================] - 81s 65ms/step - loss: 0.2381 - accuracy: 0.9196 - val_loss: 0.6526 - val_accuracy: 0.8140
# Epoch 9/10
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.2386 - accuracy: 0.9190 - val_loss: 0.6191 - val_accuracy: 0.8138
# Epoch 10/10
# 1250/1250 [==============================] - 80s 64ms/step - loss: 0.1672 - accuracy: 0.9429 - val_loss: 0.7108 - val_accuracy: 0.8086
# DenseNet121 - Test loss: 0.73386549949646; Test accuracy: 0.8047999739646912
# 157/157 [==============================] - 2s 14ms/step - loss: 4.7676 - accuracy: 0.1566
# 157/157 [==============================] - 1s 9ms/step - loss: 1.1401 - accuracy: 0.6268
# 157/157 [==============================] - 1s 6ms/step - loss: 2.1327 - accuracy: 0.2296
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1195 - accuracy: 0.7190
# 157/157 [==============================] - 2s 13ms/step - loss: 0.7339 - accuracy: 0.8048
# Best Model: DenseNet121 - Test loss: 0.73386549949646; Test accuracy: 0.8047999739646912
# Best Model: Xception - Test loss: 1.1195259094238281; Test accuracy: 0.718999981880188
