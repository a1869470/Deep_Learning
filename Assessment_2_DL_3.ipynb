# %% [markdown]
# <a href="https://colab.research.google.com/github/a1869470/Deep_Learning/blob/main/Assessment_2_DL_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import ResNet50, VGG16, MobileNet, Xception, DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Load CIFAR-10 dataset
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
num_classes = 10

# Split the full training dataset into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# Define function to create a CNN model with fine-tuning
def create_fine_tuned_model(base_model, num_classes, num_frozen_layers=100, learning_rate=0.0001):
    for layer in base_model.layers[:num_frozen_layers]:
        layer.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and compile fine-tuned models
resnet_model = create_fine_tuned_model(ResNet50(weights='imagenet', include_top=False), num_classes)
vgg_model = create_fine_tuned_model(VGG16(weights='imagenet', include_top=False), num_classes)
mobilenet_model = create_fine_tuned_model(MobileNet(weights='imagenet', include_top=False), num_classes)
xception_model = create_fine_tuned_model(Xception(weights='imagenet', include_top=False), num_classes)
densenet_model = create_fine_tuned_model(DenseNet121(weights='imagenet', include_top=False), num_classes)

# Train and evaluate fine-tuned models
models = [resnet_model, vgg_model, mobilenet_model, xception_model, densenet_model]
model_names = ['ResNet', 'VGG', 'MobileNet', 'Xception', 'DenseNet121']
histories = []

for model, model_name in zip(models, model_names):
    print(f"Fine-tuning and training {model_name}...")
    history = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_val, y_val))
    histories.append(history)
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"{model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Find the two models with the highest test accuracy
top_models = sorted(zip(models, model_names), key=lambda x: x[0].evaluate(x_test, y_test)[1], reverse=True)[:2]

# Evaluate the two best models on the test data
for model, model_name in top_models:
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Best Model: {model_name} - Test loss: {score[0]}; Test accuracy: {score[1]}")

# Plot the line graph for validation accuracy
for i, history in enumerate(histories):
    plt.plot(history.history['val_accuracy'], label=f'{model_names[i]}')

plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Fine-tuning and training ResNet...
# Epoch 1/10
# 313/313 [==============================] - 30s 50ms/step - loss: 1.9502 - accuracy: 0.3200 - val_loss: 3.2416 - val_accuracy: 0.1544
# Epoch 2/10
# 313/313 [==============================] - 13s 43ms/step - loss: 1.5929 - accuracy: 0.4355 - val_loss: 1.8233 - val_accuracy: 0.3580
# Epoch 3/10
# 313/313 [==============================] - 14s 44ms/step - loss: 1.4346 - accuracy: 0.4926 - val_loss: 1.9039 - val_accuracy: 0.3330
# Epoch 4/10
# 313/313 [==============================] - 13s 43ms/step - loss: 1.3431 - accuracy: 0.5260 - val_loss: 1.5920 - val_accuracy: 0.4376
# Epoch 5/10
# 313/313 [==============================] - 14s 43ms/step - loss: 1.2659 - accuracy: 0.5526 - val_loss: 2.2395 - val_accuracy: 0.3186
# Epoch 6/10
# 313/313 [==============================] - 14s 43ms/step - loss: 1.1940 - accuracy: 0.5752 - val_loss: 1.6962 - val_accuracy: 0.4032
# Epoch 7/10
# 313/313 [==============================] - 13s 43ms/step - loss: 1.1303 - accuracy: 0.5974 - val_loss: 2.8158 - val_accuracy: 0.2258
# Epoch 8/10
# 313/313 [==============================] - 13s 43ms/step - loss: 1.0579 - accuracy: 0.6248 - val_loss: 1.9350 - val_accuracy: 0.3730
# Epoch 9/10
# 313/313 [==============================] - 14s 44ms/step - loss: 0.9854 - accuracy: 0.6503 - val_loss: 1.5794 - val_accuracy: 0.4784
# Epoch 10/10
# 313/313 [==============================] - 14s 44ms/step - loss: 0.9069 - accuracy: 0.6791 - val_loss: 2.6041 - val_accuracy: 0.2628
# ResNet - Test loss: 2.631303548812866; Test accuracy: 0.2630000114440918
# Fine-tuning and training VGG...
# Epoch 1/10
# 313/313 [==============================] - 8s 20ms/step - loss: 1.7046 - accuracy: 0.4288 - val_loss: 1.4574 - val_accuracy: 0.5050
# Epoch 2/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.3830 - accuracy: 0.5310 - val_loss: 1.3443 - val_accuracy: 0.5336
# Epoch 3/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2956 - accuracy: 0.5574 - val_loss: 1.2861 - val_accuracy: 0.5576
# Epoch 4/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2459 - accuracy: 0.5731 - val_loss: 1.2526 - val_accuracy: 0.5650
# Epoch 5/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2114 - accuracy: 0.5840 - val_loss: 1.2329 - val_accuracy: 0.5710
# Epoch 6/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1860 - accuracy: 0.5936 - val_loss: 1.2171 - val_accuracy: 0.5692
# Epoch 7/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1663 - accuracy: 0.5991 - val_loss: 1.2042 - val_accuracy: 0.5762
# Epoch 8/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1477 - accuracy: 0.6071 - val_loss: 1.1875 - val_accuracy: 0.5818
# Epoch 9/10
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1319 - accuracy: 0.6113 - val_loss: 1.1851 - val_accuracy: 0.5852
# Epoch 10/10
# 313/313 [==============================] - 6s 19ms/step - loss: 1.1195 - accuracy: 0.6161 - val_loss: 1.1713 - val_accuracy: 0.5912
# VGG - Test loss: 1.169904112815857; Test accuracy: 0.593999981880188
# Fine-tuning and training MobileNet...
# Epoch 1/10
# 313/313 [==============================] - 6s 14ms/step - loss: 2.2455 - accuracy: 0.1717 - val_loss: 2.2100 - val_accuracy: 0.2010
# Epoch 2/10
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1905 - accuracy: 0.2010 - val_loss: 2.1857 - val_accuracy: 0.2114
# Epoch 3/10
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1708 - accuracy: 0.2121 - val_loss: 2.1727 - val_accuracy: 0.2220
# Epoch 4/10
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1585 - accuracy: 0.2188 - val_loss: 2.1638 - val_accuracy: 0.2196
# Epoch 5/10
# 313/313 [==============================] - 4s 12ms/step - loss: 2.1499 - accuracy: 0.2228 - val_loss: 2.1570 - val_accuracy: 0.2272
# Epoch 6/10
# 313/313 [==============================] - 4s 11ms/step - loss: 2.1442 - accuracy: 0.2247 - val_loss: 2.1530 - val_accuracy: 0.2274
# Epoch 7/10
# 313/313 [==============================] - 4s 11ms/step - loss: 2.1401 - accuracy: 0.2263 - val_loss: 2.1496 - val_accuracy: 0.2300
# Epoch 8/10
# 313/313 [==============================] - 3s 11ms/step - loss: 2.1367 - accuracy: 0.2267 - val_loss: 2.1463 - val_accuracy: 0.2284
# Epoch 9/10
# 313/313 [==============================] - 4s 12ms/step - loss: 2.1341 - accuracy: 0.2271 - val_loss: 2.1459 - val_accuracy: 0.2298
# Epoch 10/10
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1317 - accuracy: 0.2287 - val_loss: 2.1434 - val_accuracy: 0.2360
# MobileNet - Test loss: 2.1454248428344727; Test accuracy: 0.2264000028371811
# Fine-tuning and training Xception...
# Epoch 1/10
# 313/313 [==============================] - 32s 65ms/step - loss: 1.6336 - accuracy: 0.4424 - val_loss: 1.2484 - val_accuracy: 0.5740
# Epoch 2/10
# 313/313 [==============================] - 19s 60ms/step - loss: 0.8935 - accuracy: 0.6884 - val_loss: 0.9457 - val_accuracy: 0.6724
# Epoch 3/10
# 313/313 [==============================] - 19s 62ms/step - loss: 0.5861 - accuracy: 0.7976 - val_loss: 0.9995 - val_accuracy: 0.6724
# Epoch 4/10
# 313/313 [==============================] - 19s 62ms/step - loss: 0.3440 - accuracy: 0.8851 - val_loss: 1.0956 - val_accuracy: 0.6754
# Epoch 5/10
# 313/313 [==============================] - 19s 60ms/step - loss: 0.1775 - accuracy: 0.9452 - val_loss: 1.2627 - val_accuracy: 0.6782
# Epoch 6/10
# 313/313 [==============================] - 20s 62ms/step - loss: 0.0923 - accuracy: 0.9726 - val_loss: 1.4488 - val_accuracy: 0.6788
# Epoch 7/10
# 313/313 [==============================] - 20s 63ms/step - loss: 0.0597 - accuracy: 0.9825 - val_loss: 1.4909 - val_accuracy: 0.6802
# Epoch 8/10
# 313/313 [==============================] - 19s 61ms/step - loss: 0.0519 - accuracy: 0.9841 - val_loss: 1.6516 - val_accuracy: 0.6768
# Epoch 9/10
# 313/313 [==============================] - 19s 62ms/step - loss: 0.0475 - accuracy: 0.9851 - val_loss: 1.9281 - val_accuracy: 0.6700
# Epoch 10/10
# 313/313 [==============================] - 19s 60ms/step - loss: 0.0504 - accuracy: 0.9835 - val_loss: 1.7477 - val_accuracy: 0.6718
# Xception - Test loss: 1.8720495700836182; Test accuracy: 0.6632000207901001
# Fine-tuning and training DenseNet121...
# Epoch 1/10
# 313/313 [==============================] - 68s 79ms/step - loss: 1.2401 - accuracy: 0.5682 - val_loss: 0.8686 - val_accuracy: 0.7098
# Epoch 2/10
# 313/313 [==============================] - 22s 72ms/step - loss: 0.6525 - accuracy: 0.7746 - val_loss: 0.7340 - val_accuracy: 0.7462
# Epoch 3/10
# 313/313 [==============================] - 22s 71ms/step - loss: 0.3960 - accuracy: 0.8656 - val_loss: 0.7296 - val_accuracy: 0.7626
# Epoch 4/10
# 313/313 [==============================] - 22s 71ms/step - loss: 0.2171 - accuracy: 0.9294 - val_loss: 0.8056 - val_accuracy: 0.7610
# Epoch 5/10
# 313/313 [==============================] - 22s 70ms/step - loss: 0.1224 - accuracy: 0.9611 - val_loss: 0.8857 - val_accuracy: 0.7676
# Epoch 6/10
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0790 - accuracy: 0.9748 - val_loss: 0.9569 - val_accuracy: 0.7774
# Epoch 7/10
# 313/313 [==============================] - 23s 73ms/step - loss: 0.0617 - accuracy: 0.9798 - val_loss: 1.0096 - val_accuracy: 0.7698
# Epoch 8/10
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0717 - accuracy: 0.9760 - val_loss: 1.0737 - val_accuracy: 0.7680
# Epoch 9/10
# 313/313 [==============================] - 22s 72ms/step - loss: 0.0637 - accuracy: 0.9783 - val_loss: 1.1172 - val_accuracy: 0.7702
# Epoch 10/10
# 313/313 [==============================] - 22s 72ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 1.1471 - val_accuracy: 0.7730
# DenseNet121 - Test loss: 1.1510761976242065; Test accuracy: 0.772599995136261
# 157/157 [==============================] - 2s 14ms/step - loss: 2.6313 - accuracy: 0.2630
# 157/157 [==============================] - 1s 8ms/step - loss: 1.1699 - accuracy: 0.5940
# 157/157 [==============================] - 1s 6ms/step - loss: 2.1454 - accuracy: 0.2264
# 157/157 [==============================] - 2s 10ms/step - loss: 1.8720 - accuracy: 0.6632
# 157/157 [==============================] - 2s 13ms/step - loss: 1.1511 - accuracy: 0.7726
# Best Model: DenseNet121 - Test loss: 1.1510761976242065; Test accuracy: 0.772599995136261
# Best Model: Xception - Test loss: 1.8720495700836182; Test accuracy: 0.6632000207901001
